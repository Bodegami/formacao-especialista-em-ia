# %%
# %pip install langmem
# Out:
# Collecting langmem
#   Downloading langmem-0.0.30-py3-none-any.whl.metadata (6.8 kB)
# Collecting langchain-anthropic>=0.3.3 (from langmem)
#   Downloading langchain_anthropic-1.7.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: langchain-core>=0.3.46 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langmem) (1.6.2)
# Requirement already satisfied: langchain-openai>=0.3.1 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langmem) (1.6.0)
# Requirement already satisfied: langchain>=0.3.15 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langmem) (1.4.0)
# Requirement already satisfied: langgraph-checkpoint>=2.0.12 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langmem) (4.2.0)
# Requirement already satisfied: langgraph<2,>=0.6.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langmem) (1.2.11)
# Requirement already satisfied: langsmith>=0.3.8 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langmem) (0.11.1)
# Collecting trustcall>=0.0.39 (from langmem)
#   Downloading trustcall-0.0.39-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langgraph<2,>=0.6.0->langmem) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langgraph<2,>=0.6.0->langmem) (0.4.3)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langgraph<2,>=0.6.0->langmem) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langgraph<2,>=0.6.0->langmem) (4.0.1)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-core>=0.3.46->langmem) (0.17.0)
# Requirement already satisfied: anyio in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.3.46->langmem) (4.14.2)
# Requirement already satisfied: certifi in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.3.46->langmem) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.3.46->langmem) (1.0.9)
# Requirement already satisfied: idna in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core>=0.3.46->langmem) (3.19)
# Requirement already satisfied: h11>=0.16 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core>=0.3.46->langmem) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.3.46->langmem) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langgraph-checkpoint>=2.0.12->langmem) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<2,>=0.6.0->langmem) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<2,>=0.6.0->langmem) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langsmith>=0.3.8->langmem) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langsmith>=0.3.8->langmem) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langsmith>=0.3.8->langmem) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langsmith>=0.3.8->langmem) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langsmith>=0.3.8->langmem) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph<2,>=0.6.0->langmem) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph<2,>=0.6.0->langmem) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph<2,>=0.6.0->langmem) (0.4.4)
# Collecting anthropic<2.0.0,>=0.120.0 (from langchain-anthropic>=0.3.3->langmem)
#   Downloading anthropic-1.5.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting docstring-parser<1,>=0.15 (from anthropic<2.0.0,>=0.120.0->langchain-anthropic>=0.3.3->langmem)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: httpx2<3,>=2.0.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from anthropic<2.0.0,>=0.120.0->langchain-anthropic>=0.3.3->langmem) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from anthropic<2.0.0,>=0.120.0->langchain-anthropic>=0.3.3->langmem) (0.16.0)
# Requirement already satisfied: httpcore2==2.12.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from httpx2<3,>=2.0.0->anthropic<2.0.0,>=0.120.0->langchain-anthropic>=0.3.3->langmem) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from httpx2<3,>=2.0.0->anthropic<2.0.0,>=0.120.0->langchain-anthropic>=0.3.3->langmem) (0.10.4)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-openai>=0.3.1->langmem) (3.3.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from langchain-openai>=0.3.1->langmem) (0.14.0)
# Requirement already satisfied: regex in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.3.1->langmem) (2026.7.19)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from requests>=2.0.0->langsmith>=0.3.8->langmem) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/lib/python3.12/site-packages (from requests>=2.0.0->langsmith>=0.3.8->langmem) (2.7.0)
# Collecting dydantic<1.0.0,>=0.0.8 (from trustcall>=0.0.39->langmem)
#   Downloading dydantic-0.0.8-py3-none-any.whl.metadata (3.6 kB)
# Downloading langmem-0.0.30-py3-none-any.whl (67 kB)
# Downloading langchain_anthropic-1.7.2-py3-none-any.whl (60 kB)
# Downloading anthropic-1.5.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.4 MB/s  0:00:00
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading trustcall-0.0.39-py3-none-any.whl (30 kB)
# Downloading dydantic-0.0.8-py3-none-any.whl (8.6 kB)
# Installing collected packages: docstring-parser, dydantic, anthropic, langchain-anthropic, trustcall, langmem
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [langmem]m5/6 [langmem]c]
# Successfully installed anthropic-1.5.0 docstring-parser-0.18.0 dydantic-0.0.8 langchain-anthropic-1.7.2 langmem-0.0.30 trustcall-0.0.39
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from dotenv import load_dotenv
from pydantic import BaseModel
from typing_extensions import TypedDict, Literal, Annotated
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage
from langchain_core.tools import tool
# from langchain.agents import AgentExecutor
from langgraph.graph import StateGraph, END, add_messages
from langgraph.prebuilt import ToolNode, create_react_agent
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langmem import create_manage_memory_tool, create_search_memory_tool
from langgraph.store.memory import InMemoryStore
from IPython.display import Image, display
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolNode

# %%
load_dotenv()
os.environ['GOOGLE_API_KEY'] = os.getenv('GEMINI_API_KEY')
os.environ['TAVILY_API_KEY'] = os.getenv('TAVILY_API_KEY')

# Perfil do usuário
profile = {
    "name": "Sarah",
    "full_name": "Sarah Chen",
    "user_profile_background": "Engenheira de software sênior liderando uma equipe de 5 desenvolvedores",
}

# Instruções para o prompt
prompt_instructions = {
    "triage_rules": {
        "ignore": "Newsletters, spam, comunicados gerais da empresa",
        "notify": "Membro da equipe doente, notificações do sistema de build, atualizações de status de projeto",
        "respond": "Perguntas diretas de membros da equipe, solicitações de reunião, relatórios de bugs críticos",
    },
    "agent_instructions": """Você é um assistente executivo altamente eficiente. Execute as tarefas solicitadas de forma direta, sem diálogos desnecessários. Responda apenas com a chamada das ferramentas, a menos que seja estritamente necessário fornecer uma resposta textual.

Tarefas:
- Responder ao e-mail de entrada.
- Salvar a tarefa de acompanhamento na memória.
- Sugerir uma próxima ação, como 'Gostaria que eu agendasse uma reunião para discutir isso?'"""
}

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# Roteador para classificar a intenção do e-mail
class Router(BaseModel):
    # Raciocínio por trás da classificação
    reasoning: str
    # Classificação do e-mail como 'ignorar', 'notificar' ou 'responder'
    classification: Literal["ignore", "notify", "respond"]

llm_router = llm.with_structured_output(Router)

# Prompt do sistema para a triagem de e-mails
triage_system_prompt = """Você é um assistente de triagem de e-mails.
Classifique os e-mails como 'ignore', 'notify' ou 'respond'.

Regras:
- ignore: {triage_no}
- notify: {triage_notify}
- respond: {triage_email}
"""

# Prompt do usuário, que contém os dados do e-mail
triage_user_prompt = """
De: {author}
Para: {to}
Assunto: {subject}
Corpo da Mensagem:
{email_thread}
"""
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
# --- 3. Ferramentas ---
@tool
def write_email(to: str, subject: str, content: str) -> str:
    """Envia um e-mail para o destinatário especificado com o assunto e conteúdo fornecidos."""
    return json.dumps({"to": to, "subject": subject, "content": content})

@tool
def schedule_meeting(attendees: list[str], subject: str, duration_minutes: int, preferred_day: str) -> str:
    """Agenda uma reunião com os participantes especificados."""
    return f"Reunião '{subject}' agendada para {preferred_day} com {len(attendees)} participantes"

@tool
def check_calendar_availability(day: str) -> str:
    """Verifica os horários disponíveis para o dia fornecido."""
    return f"Horários disponíveis em {day}: 9:00, 14:00, 16:00"

google_embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")
store = InMemoryStore(index={"embed": google_embeddings})

manage_memory_tool = create_manage_memory_tool(
    store=store,
    namespace=("email_assistant", "{langgraph_user_id}", "collection")
)
search_memory_tool = create_search_memory_tool(
    store=store,
    namespace=("email_assistant", "{langgraph_user_id}", "collection")
)

agent_system_prompt_memory = """
< Função >
Você é o(a) assistente executivo(a) de {full_name}. Sua prioridade é maximizar o desempenho de {name}.
{instructions}
</ Função >

< Ferramentas >
1. write_email(to, subject, content) - Envia e-mails
2. schedule_meeting(attendees, subject, duration_minutes, preferred_day) - Agenda reuniões
3. check_calendar_availability(day) - Verifica horários disponíveis
4. manage_memory - Armazena informações na memória
5. search_memory - Busca informações na memória
</ Ferramentas >
"""

def create_prompt(state):
    return [
        {"role": "system", "content": agent_system_prompt_memory.format(
            instructions=prompt_instructions["agent_instructions"], **profile
        )},
    ] + state['messages']

tools = [write_email, schedule_meeting, check_calendar_availability, manage_memory_tool, search_memory_tool]

response_agent = create_react_agent(
    model=llm,
    tools=tools,
    prompt=create_prompt,
    store=store
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# /var/folders/t0/pj9mr33s4xsdgcv27jrjrpsm0000gn/T/ipykernel_5674/2199321643.py:53: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   response_agent = create_react_agent(

# %%
# --- 4. Grafo de triagem ---
class State(TypedDict):
    email_input: dict
    messages: Annotated[list, add_messages]

def triage_router(state: State) -> dict:
    author = state['email_input']['from']
    to = state['email_input']['to']
    subject = state['email_input']['subject']
    body = state['email_input']['body']

    system_prompt = triage_system_prompt.format(
        triage_no=prompt_instructions["triage_rules"]["ignore"],
        triage_notify=prompt_instructions["triage_rules"]["notify"],
        triage_email=prompt_instructions["triage_rules"]["respond"]
    )
    user_prompt = triage_user_prompt.format(
        author=author,
        to=to,
        subject=subject,
        email_thread=body
    )
    result = llm_router.invoke(
        [{"role": "system", "content": system_prompt},
         {"role": "user", "content": user_prompt}]
    )

    if result.classification == "respond":
        message_content = json.dumps({
            "sender": author,
            "recipient": to,
            "subject": subject,
            "body": body
        })
        return {
            "messages": [
                HumanMessage(content=f"Respond to the email {message_content}")
            ],
            "__next__": "response_agent"
        }
    elif result.classification in ["ignore", "notify"]:
        return {"__next__": END}
    else:
        raise ValueError(f"Invalid classification: {result.classification}")

# %%
# --- 5. Construção do grafo ---
builder = StateGraph(State)
builder.add_node("triage_router", triage_router)
builder.add_node("response_agent", response_agent)
builder.add_node("tool_node", ToolNode(tools))
builder.set_entry_point("triage_router")

# Condições
builder.add_conditional_edges(
    "triage_router",
    lambda state: state.get("__next__", None),
    {"response_agent": "response_agent", "END": END}
)

def route_to_tools(state):
    last_message = state["messages"][-1]
    if getattr(last_message, "tool_calls", None):
        return "tool_node"
    return END

builder.add_conditional_edges(
    "response_agent",
    route_to_tools,
    {"tool_node": "tool_node", END: END}
)
builder.add_edge("tool_node", "response_agent")

email_agent = builder.compile()

# %%
# Gera a imagem do grafo em formato PNG
display(Image(email_agent.get_graph(xray=True).draw_mermaid_png()))

# %%
# --- 6. Human-in-the-loop ---
def human_in_the_loop_schedule(email_sender, email_recipient, email_subject):
    # Checa memória se já há reunião
    search_results = search_memory_tool.invoke(
        {"query": f"Reunião agendada para {email_sender}"},
        config=config
    )
    if isinstance(search_results, str):
        # retorna string, transforma em dict vazio
        search_results = {}

    if search_results.get("results"):
        email_content = write_email.invoke(
            {
                "to": email_sender,
                "subject": f"Re: {email_subject}",
                "content": "Olá, acabei de agendar uma conversa contigo para discutirmos esse assunto."
            },
            config=config
        )
        print("================== Tool Message ==================")
        print(f"Name: write_email\nContent: {email_content}")
        return

    decision = input(f"Deseja agendar uma reunião para discutir o pedido de {email_sender}? (sim/não): ").strip().lower()
    
    if decision == "sim":
        meeting_output = schedule_meeting.invoke(
            {
                "attendees": [email_recipient.split('<')[0].strip(), email_sender.split('<')[0].strip()],
                "subject": f"Acompanhamento do pedido de {email_sender}",
                "duration_minutes": 30,
                "preferred_day": "amanhã"
            },
            config=config
        )
        print("================== Tool Message ==================")
        print(f"Name: schedule_meeting\nContent: {meeting_output}")

        memory_output = manage_memory_tool.invoke(
            {"action": "create", "content": f"Reunião agendada para discutir o pedido de {email_sender}"},
            config=config
        )
        print("================== Tool Message ==================")
        print(f"Name: manage_memory\nContent: {memory_output}")

        email_content = write_email.invoke(
            {
                "to": email_sender,
                "subject": f"Re: {email_subject}",
                "content": "Já agendei uma reunião contigo para discutirmos esse assunto."
            },
            config=config
        )
        print("================== Tool Message ==================")
        print(f"Name: write_email\nContent: {email_content}")

    else:
        email_content = write_email.invoke(
            {
                "to": email_sender,
                "subject": f"Re: {email_subject}",
                "content": "Estou acompanhando seu pedido e entrarei em contato assim que houver novidades."
            },
            config=config
        )
        print("================== Tool Message ==================")
        print(f"Name: write_email\nContent: {email_content}")

        memory_output = manage_memory_tool.invoke(
            {"action": "create", "content": f"E-mail de acompanhamento enviado para {email_sender}"},
            config=config
        )
        print("================== Tool Message ==================")
        print(f"Name: manage_memory\nContent: {memory_output}")

# %%
# --- 7. Exemplo de execução ---
config = {"configurable": {"langgraph_user_id": "lance"}}

# Pré-popula a memória
initial_memory_content = "Acompanhamento necessário: Alice Smith perguntou sobre os endpoints de API ausentes na documentação do serviço de autenticação (/auth/refresh e /auth/validate). Sarah precisa revisar e esclarecer se eles foram intencionalmente omitidos ou se a documentação precisa de atualização."
manage_memory_tool.invoke({"action": "create", "content": initial_memory_content}, config=config)

email_input = {
    "from": "Alice Smith <alice.smith@company.com>",
    "to": "Sarah Chen <sarah.chen@company.com>",
    "subject": "Acompanhamento",
    "body": "Olá Sarah, como está minha solicitação?"
}

# 1️⃣ Agente responde
response = email_agent.invoke({"email_input": email_input}, config=config)
for msg in response["messages"]:
    if isinstance(msg, ToolMessage):
        print("================== Mensagem da Ferramenta ==================")
        print(f"Nome: {msg.name}\nConteúdo: {msg.content}")

# 2️⃣ Human-in-the-loop
human_in_the_loop_schedule(email_input["from"], email_input["to"], email_input["subject"])
# Out:
# ================== Mensagem da Ferramenta ==================
# Nome: search_memory
# Conteúdo: [{"namespace":["email_assistant","lance","collection"],"key":"f4c3051d-3495-490c-81f5-7c384e6e0452","value":{"content":"Reunião agendada para discutir o pedido de Alice Smith <alice.smith@company.com>"},"created_at":"2026-09-12T01:02:00.049371+00:00","updated_at":"2026-09-12T01:02:00.049375+00:00","score":0.7147227540563732},{"namespace":["email_assistant","lance","collection"],"key":"46ed0040-ebae-4d1a-92c8-f21111f0b523","value":{"content":"Acompanhamento necessário: Alice Smith perguntou sobre os endpoints de API ausentes na documentação do serviço de autenticação (/auth/refresh e /auth/validate). Sarah precisa revisar e esclarecer se eles foram intencionalmente omitidos ou se a documentação precisa de atualização."},"created_at":"2026-09-12T01:01:02.960296+00:00","updated_at":"2026-09-12T01:01:02.960302+00:00","score":0.7112515537651132},{"namespace":["email_assistant","lance","collection"],"key":"9423f1c8-74cd-471c-8346-1ea9135c8ea4","value":{"content":"Acompanhamento necessário: Alice Smith perguntou sobre os endpoints de API ausentes na documentação do serviço de autenticação (/auth/refresh e /auth/validate). Sarah precisa revisar e esclarecer se eles foram intencionalmente omitidos ou se a documentação precisa de atualização."},"created_at":"2026-09-12T01:02:48.209916+00:00","updated_at":"2026-09-12T01:02:48.209920+00:00","score":0.7112515537651132}]
# ================== Mensagem da Ferramenta ==================
# Nome: write_email
# Conteúdo: {"to": "alice.smith@company.com", "subject": "Re: Acompanhamento", "content": "Ol\u00e1 Alice,\n\nEstou revisando a sua solicita\u00e7\u00e3o referente aos endpoints de API ausentes (/auth/refresh e /auth/validate) no servi\u00e7o de autentica\u00e7\u00e3o. Responderei assim que tiver uma defini\u00e7\u00e3o sobre a omiss\u00e3o ou necessidade de atualiza\u00e7\u00e3o.\n\nAtenciosamente,\nSarah Chen"}
# ================== Mensagem da Ferramenta ==================
# Nome: manage_memory
# Conteúdo: created memory 8efc0871-63de-4f18-897e-1ef75e50a9e1
# ================== Tool Message ==================
# Name: write_email
# Content: {"to": "Alice Smith <alice.smith@company.com>", "subject": "Re: Acompanhamento", "content": "Estou acompanhando seu pedido e entrarei em contato assim que houver novidades."}
# ================== Tool Message ==================
# Name: manage_memory
# Content: created memory 665339ff-737a-4ca6-b20a-e347c0b65cf4
