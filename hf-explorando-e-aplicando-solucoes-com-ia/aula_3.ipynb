# %% [markdown]
# # Removendo o background de imagens

# %% [markdown]
# ## Selecionando o modelo

# %%
# %pip install skimage torchvision
# Out:
# /Users/devbodegami/Projetos/formacao-especialista-em-ia/.venv-test/bin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline

image_path = "https://farm5.staticflickr.com/4007/4322154488_997e69e4cf_z.jpg"
pipe = pipeline("image-segmentation", model="briaai/RMBG-1.4", trust_remote_code=True, device=1) # device=0 for GPU, device=-1 for CPU

pillow_mask = pipe(image_path, return_mask = True) # outputs a pillow mask
pillow_image = pipe(image_path) # applies mask on input and returns a pillow image

# %%
pillow_mask
# Out:
# <PIL.Image.Image image mode=L size=640x511>

# %%
pillow_image
# Out:
# <PIL.Image.Image image mode=RGBA size=640x511>
