# %% [markdown]
# Começando a Aula de Python

# %%
5
# Out:
# 5

# %%
print(5)
# Out:
# 5

# %%
print("Olá mundo!")
# Out:
# Olá mundo!

# %%
print("Olá mundo" + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2541/561623240.py in <cell line: 0>()
# ----> 1 print("Olá mundo" + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("Olá mundo" + " 5")
# Out:
# Olá mundo 5
